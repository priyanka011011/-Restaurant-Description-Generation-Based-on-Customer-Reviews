# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanka011011/-Restaurant-Description-Generation-Based-on-Customer-Reviews/blob/main/Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
from nltk.corpus import stopwords
import re
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from pprint import pprint
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
data = pd.read_csv('/content/drive/MyDrive/zomato.csv')
df = data.head(1000)
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
# 3      South Indian, North Indian                         300
# 4        North Indian, Rajasthani                         600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 2          Buffet    Banashankari
# 3          Buffet    Banashankari
# 4          Buffet    Banashankari

# %%
df.shape
# Out:
# (1000, 17)

# %%
col = ['phone','listed_in(type)']

# %%
df = df.drop(labels = col,axis = 1)

# %%
df_review = df[['url','name','rest_type','reviews_list','location']]
df_review.reset_index(drop = 'index',inplace = True)

# %%
df_review.head()
# Out:
#                                                  url                   name  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...                  Jalsa
# 1  https://www.zomato.com/bangalore/spice-elephan...         Spice Elephant
# 2  https://www.zomato.com/SanchurroBangalore?cont...        San Churro Cafe
# 3  https://www.zomato.com/bangalore/addhuri-udupi...  Addhuri Udupi Bhojana
# 4  https://www.zomato.com/bangalore/grand-village...          Grand Village
#
#              rest_type                                       reviews_list  \
# 0        Casual Dining  [('Rated 4.0', 'RATED\n  A beautiful place to ...
# 1        Casual Dining  [('Rated 4.0', 'RATED\n  Had been here for din...
# 2  Cafe, Casual Dining  [('Rated 3.0', "RATED\n  Ambience is not that ...
# 3          Quick Bites  [('Rated 4.0', "RATED\n  Great food and proper...
# 4        Casual Dining  [('Rated 4.0', 'RATED\n  Very good restaurant ...
#
#        location
# 0  Banashankari
# 1  Banashankari
# 2  Banashankari
# 3  Banashankari
# 4  Basavanagudi

# %%
df_review.reviews_list.replace(to_replace=r'\\n',value=' ',regex=True,inplace=True)
df_review.reviews_list.replace(to_replace=r"'\(',",value=' ',regex=True,inplace=True)
df_review.reviews_list.replace(to_replace=r'"',value="'",regex=True,inplace=True)
# Out:
# <ipython-input-8-cf6d209f47df>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_review.reviews_list.replace(to_replace=r'\\n',value=' ',regex=True,inplace=True)
# <ipython-input-8-cf6d209f47df>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_review.reviews_list.replace(to_replace=r"'\(',",value=' ',regex=True,inplace=True)
# <ipython-input-8-cf6d209f47df>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_review.reviews_list.replace(to_replace=r'"',value="'",regex=True,inplace=True)

# %%
df_review.head()
# Out:
#                                                  url                   name  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...                  Jalsa
# 1  https://www.zomato.com/bangalore/spice-elephan...         Spice Elephant
# 2  https://www.zomato.com/SanchurroBangalore?cont...        San Churro Cafe
# 3  https://www.zomato.com/bangalore/addhuri-udupi...  Addhuri Udupi Bhojana
# 4  https://www.zomato.com/bangalore/grand-village...          Grand Village
#
#              rest_type                                       reviews_list  \
# 0        Casual Dining  [('Rated 4.0', 'RATED   A beautiful place to d...
# 1        Casual Dining  [('Rated 4.0', 'RATED   Had been here for dinn...
# 2  Cafe, Casual Dining  [('Rated 3.0', 'RATED   Ambience is not that g...
# 3          Quick Bites  [('Rated 4.0', 'RATED   Great food and proper ...
# 4        Casual Dining  [('Rated 4.0', 'RATED   Very good restaurant i...
#
#        location
# 0  Banashankari
# 1  Banashankari
# 2  Banashankari
# 3  Banashankari
# 4  Basavanagudi

# %%
star = []
review = []
restaurant = []
restaurant_type = []
location = []
url = []
for i in range(len(df_review)):
    for j in range(len(re.split("'Rated ",df_review.reviews_list[i]))-1):
        restaurant.append(df_review.name[i])
        location.append(df_review.location[i])
        url.append(df_review.url[i])
        restaurant_type.append(df_review.rest_type[i])
        star.append(re.split("'Rated ",df_review.reviews_list[i])[j+1].split("',")[0])
        review.append(re.split("'Rated ",df_review.reviews_list[i])[j+1].split("',")[1])

# %%
data = pd.DataFrame([url,restaurant,restaurant_type,star,review,location])

# %%
data = data.T

# %%
data.columns = ['url','restaurant','restaurant_type','rating','review','location']

# %%
data.review.replace(to_replace=r" 'RATED   ",value='',regex=True,inplace=True)
data.review.replace(to_replace=r"'\), \(",value='',regex=True,inplace=True)

# %%
data.review.replace(to_replace=r"[^a-zA-Z0-9']",value=' ',regex=True,inplace = True)

# %%
data.tail(10)
# Out:
#                                                      url       restaurant  \
# 18468  https://www.zomato.com/bangalore/paradise-jp-n...         Paradise
# 18469  https://www.zomato.com/bangalore/paradise-jp-n...         Paradise
# 18470  https://www.zomato.com/bangalore/paradise-jp-n...         Paradise
# 18471  https://www.zomato.com/bangalore/paradise-jp-n...         Paradise
# 18472  https://www.zomato.com/bangalore/paradise-jp-n...         Paradise
# 18473  https://www.zomato.com/bangalore/kabab-mehal-1...      Kabab Mehal
# 18474  https://www.zomato.com/bangalore/kabab-mehal-1...      Kabab Mehal
# 18475  https://www.zomato.com/bangalore/kabab-mehal-1...      Kabab Mehal
# 18476  https://www.zomato.com/bangalore/mughlai-kitch...  Mughlai Kitchen
# 18477  https://www.zomato.com/bangalore/mughlai-kitch...  Mughlai Kitchen
#
#       restaurant_type rating  \
# 18468   Casual Dining    4.0
# 18469   Casual Dining    1.0
# 18470   Casual Dining    5.0
# 18471   Casual Dining    4.0
# 18472   Casual Dining    1.0
# 18473     Quick Bites    3.0
# 18474     Quick Bites    4.0
# 18475     Quick Bites    4.0
# 18476             NaN    5.0
# 18477             NaN    3.0
#
#                                                   review  location
# 18468  So I have had chicken here before  Had no idea...  JP Nagar
# 18469  I love biryani  but really disappointed servic...  JP Nagar
# 18470  The name itself says the brand   already been ...  JP Nagar
# 18471  So I have had chicken here before  Had no idea...  JP Nagar
# 18472  I love biryani  but really disappointed servic...  JP Nagar
# 18473  We tried Chicken Shawarma and Some Panner Grav...  JP Nagar
# 18474  The place is located next to axis bank and it ...  JP Nagar
# 18475  This cute little place is right beside where I...  JP Nagar
# 18476  Ordered Chicken Kadai and butter Rotis  Extrem...       BTM
# 18477  Simple food with great north indian taste Had ...       BTM

# %%
data.restaurant.replace(to_replace=r"[^a-zA-Z0-9']",value=' ',regex=True,inplace = True)

# %%
data_unique = data.drop_duplicates().reset_index(drop = 'index')

# %%
data_unique.to_csv('restaurant_review.csv',encoding='UTF-8',index=False)
